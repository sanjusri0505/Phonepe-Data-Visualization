# %%
import os
import json
import pandas as pd

# %%
#aggregated_transaction

# Base path
path = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/aggregated/transaction/country/india/state'

states = os.listdir(path)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"Transaction_type":[],"Transaction_count":[],"Transaction_amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data = json.load(data)
                    #print(json_data)
                    for i in json_data['data']['transactionData'] :
                        name = i['name']
                        count=i['paymentInstruments'][0]['count']
                        amount = i['paymentInstruments'][0]['amount']
                        columns['Transaction_type'].append(name)
                        columns['Transaction_count'].append(count)
                        columns['Transaction_amount'].append(amount)
                        columns['States'].append(state)
                        columns['years'].append(year)
                        columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

aggregated_transaction = pd.DataFrame(columns)
aggregated_transaction['States']= aggregated_transaction['States'].str.replace("-"," ")
aggregated_transaction['States']= aggregated_transaction['States'].str.title()
#aggregated_transaction['States'].unique()
aggregated_transaction

# %%
#aggregated_user

# Base path
path1 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/aggregated/user/country/india/state'

states = os.listdir(path1)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"User_brand":[],"User_count":[],"User_percentage":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path1,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data1 = json.load(data)
                    #print(json_data1)
                    for i in json_data1['data']['usersByDevice'] :
                        brand = i['brand']
                        count =i['count']
                        percentage = i['percentage']
                        columns['User_brand'].append(brand)
                        columns['User_count'].append(count)
                        columns['User_percentage'].append(percentage)
                        columns['States'].append(state)
                        columns['years'].append(year)
                        columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

aggregated_user = pd.DataFrame(columns)
aggregated_user['States']= aggregated_user['States'].str.replace("-"," ")
aggregated_user['States']= aggregated_user['States'].str.title()
#aggregated_user['States'].unique()
aggregated_user

# %%
#aggregated_insurance

# Base path
path2 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/aggregated/insurance/country/india/state'


states = os.listdir(path2)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"Name":[],"count":[],"amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path2,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data2 = json.load(data)
                        for i in json_data2['data']['transactionData'] :
                            name = i['name']
                            count=i['paymentInstruments'][0]['count']
                            amount = i['paymentInstruments'][0]['amount']
                            columns['Name'].append(name)
                            columns['count'].append(count)
                            columns['amount'].append(amount)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

aggregated_insurance = pd.DataFrame(columns)
aggregated_insurance['States']= aggregated_insurance['States'].str.replace("-"," ")
aggregated_insurance['States']= aggregated_insurance['States'].str.title()
#aggregated_insurance['States'].unique()
aggregated_insurance

# %%
# map_transaction

# Base path
path3 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/map/transaction/hover/country/india/state'


states = os.listdir(path3)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"district_name":[],"Transaction_count":[],"Transaction_amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path3,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data3 = json.load(data)
                        for i in json_data3['data']['hoverDataList'] :
                            name = i['name']
                            count=i['metric'][0]['count']
                            amount = i['metric'][0]['amount']
                            columns['district_name'].append(name)
                            columns['Transaction_count'].append(count)
                            columns['Transaction_amount'].append(amount)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

map_transaction = pd.DataFrame(columns)
map_transaction['States']= map_transaction['States'].str.replace("-"," ")
map_transaction['States']= map_transaction['States'].str.title()
#map_transaction['States'].unique()
map_transaction

# %%
# map_user

# Base path
path4 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/map/user/hover/country/india/state'


states = os.listdir(path4)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"district_name":[],"registered_user":[],"appOpens":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path4,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data4 = json.load(data)
                        for i in json_data4['data']['hoverData'].items():
                                #print(i[0])
                                #print(i[1]['registeredUsers'])
                                #print(i[1]['appOpens'])
                                district_name = i[0]
                                registered_user=i[1]['registeredUsers']
                                appOpens = i[1]['appOpens']
                                columns['district_name'].append(district_name)
                                columns['registered_user'].append(registered_user)
                                columns['appOpens'].append(appOpens)
                                columns['States'].append(state)
                                columns['years'].append(year)
                                columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

map_user = pd.DataFrame(columns)
map_user['States']= map_user['States'].str.replace("-"," ")
map_user['States']= map_user['States'].str.title()
#map_user['States'].unique()
map_user

# %%
#map_insurance

# Base path
path5 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/map/insurance/hover/country/india/state'


states = os.listdir(path5)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"district_name":[],"Count":[],"amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path5,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data5 = json.load(data)
                        for i in json_data5['data']['hoverDataList'] :
                            name = i['name']
                            count=i['metric'][0]['count']
                            amount = i['metric'][0]['amount']
                            columns['district_name'].append(name)
                            columns['Count'].append(count)
                            columns['amount'].append(amount)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

map_insurance = pd.DataFrame(columns)
map_insurance['States']= map_insurance['States'].str.replace("-"," ")
map_insurance['States']= map_insurance['States'].str.title()
#map_insurance['States'].unique()
map_insurance

# %%
# top_transaction_districts

# Base path
path6 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/top/transaction/country/india/state'


states = os.listdir(path6)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"district_name":[],"Transaction_count":[],"Transaction_amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path6,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data6 = json.load(data)
                        for i in json_data6['data']['districts']:
                            entityName = i['entityName']
                            count=i['metric']['count']
                            amount = i['metric']['amount']
                            columns['district_name'].append(entityName)
                            columns['Transaction_count'].append(count)
                            columns['Transaction_amount'].append(amount)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

top_transaction_district = pd.DataFrame(columns)
top_transaction_district['States']= top_transaction_district['States'].str.replace("-"," ")
top_transaction_district['States']= top_transaction_district['States'].str.title()
#top_transaction_district['States'].unique()
top_transaction_district

# %%
# top_transaction_pincodes

# Base path
path7 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/top/transaction/country/india/state'


states = os.listdir(path7)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"pincode":[],"Transaction_count":[],"Transaction_amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path7,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data7 = json.load(data)
                        for i in json_data7['data']['pincodes']:
                            entityName = i['entityName']
                            count=i['metric']['count']
                            amount = i['metric']['amount']
                            columns['pincode'].append(entityName)
                            columns['Transaction_count'].append(count)
                            columns['Transaction_amount'].append(amount)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

top_transaction_pincode = pd.DataFrame(columns)
top_transaction_pincode['States']= top_transaction_pincode['States'].str.replace("-"," ")
top_transaction_pincode['States']= top_transaction_pincode['States'].str.title()
#top_transaction_pincode['States'].unique()
top_transaction_pincode

# %%
# top_user_districts

# Base path
path8 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/top/user/country/india/state'


states = os.listdir(path8)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"district_name":[],"registeredUsers":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path8,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data8 = json.load(data)
                        for i in json_data8['data']['districts']:
                            name = i['name']
                            registeredUsers=i['registeredUsers']
                            columns['district_name'].append(name)
                            columns['registeredUsers'].append(registeredUsers)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

top_User_district = pd.DataFrame(columns)
top_User_district['States']= top_User_district['States'].str.replace("-"," ")
top_User_district['States']= top_User_district['States'].str.title()
#top_User_district['States'].unique()
top_User_district

# %%
# top_user_pincode

# Base path
path9 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/top/user/country/india/state'


states = os.listdir(path9)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"pincode":[],"registeredUsers":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path9,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data9 = json.load(data)
                        for i in json_data9['data']['pincodes']:
                            name = i['name']
                            registeredUsers=i['registeredUsers']
                            columns['pincode'].append(name)
                            columns['registeredUsers'].append(registeredUsers)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                except Exception:
                    pass

top_User_pincode = pd.DataFrame(columns)
top_User_pincode['States']= top_User_pincode['States'].str.replace("-"," ")
top_User_pincode['States']= top_User_pincode['States'].str.title()
#top_User_pincode['States'].unique()
top_User_pincode

# %%
#top_insurance_districts

path10 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/top/insurance/country/india/state'


states = os.listdir(path10)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"district_name":[],"count":[],"amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path10,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data10 = json.load(data)
                        for i in json_data10['data']['districts']:
                            entityName = i['entityName']
                            count=i['metric']['count']
                            amount = i['metric']['amount']
                            columns['district_name'].append(entityName)
                            columns['count'].append(count)
                            columns['amount'].append(amount)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                        
                except Exception:
                    pass

top_insurance_districts = pd.DataFrame(columns)
top_insurance_districts['States']= top_insurance_districts['States'].str.replace("-"," ")
top_insurance_districts['States']= top_insurance_districts['States'].str.title()
#top_insurance_districts['States'].unique()
top_insurance_districts

# %%
#top_insurance_pincode

path11 = r'C:/Users/sanju/OneDrive/Desktop/PhonePe/pulse/data/top/insurance/country/india/state'


states = os.listdir(path11)
years = [str(year) for year in range(2018, 2025)]
files_per_year = [f"{j}.json" for j in range(1, 5)]

columns={"States":[],"years":[],"Quarter":[],"pincode":[],"count":[],"amount":[]}
# Iterate through states, years, and files
for state in states:
    for year in years:
        for file_name in files_per_year:
            file_path = os.path.join(path11,state,year,file_name)
            if os.path.exists(file_path):
                try:
                    # Open file and load JSON into variable json_data
                    with open(file_path, "r") as data:
                        json_data11 = json.load(data)
                        for i in json_data11['data']['pincodes']:
                            entityName = i['entityName']
                            count=i['metric']['count']
                            amount = i['metric']['amount']
                            columns['pincode'].append(entityName)
                            columns['count'].append(count)
                            columns['amount'].append(amount)
                            columns['States'].append(state)
                            columns['years'].append(year)
                            columns['Quarter'].append(int(file_name.strip('.json')))
                        
                except Exception:
                    pass

top_insurance_pincode= pd.DataFrame(columns)
top_insurance_pincode['States']= top_insurance_pincode['States'].str.replace("-"," ")
top_insurance_pincode['States']= top_insurance_pincode['States'].str.title()
#top_insurance_pincode['States'].unique()
top_insurance_pincode

# %%
# Tables Creation

import pymysql

# Using MYSQL Connection
mydb = pymysql.connect(
     host = 'localhost',
     user = 'root',
     password = 'root',
     database = 'phonepe_transactions'
)

mycursor = mydb.cursor()

# Aggregated_transaction

query1= ("""CREATE TABLE if not exists aggregated_transaction(States VARCHAR(250), 
                                                                      years INT,  
                                                                      Quarter INT, 
                                                                      Transaction_type VARCHAR(250),
                                                                      Transaction_count INT,
                                                                      Transaction_amount bigint)""")
mycursor.execute(query1)
mydb.commit()

# Insert values into table
insert_query1 = """
        INSERT INTO aggregated_transaction 
        (States, years, Quarter, Transaction_type, Transaction_count, Transaction_amount) 
        VALUES (%s, %s, %s, %s, %s, %s)
        """

data = aggregated_transaction.values.tolist()
mycursor.executemany(insert_query1,data)
mydb.commit()

# Aggregated_User

query2= ("""CREATE TABLE if not exists aggregated_user(States VARCHAR(250), 
                                                                      years INT,  
                                                                      Quarter INT, 
                                                                      User_brand VARCHAR(250),
                                                                      User_count bigint,
                                                                      User_percentage FLOAT )""")
mycursor.execute(query2)
mydb.commit()

# Insert values into table
insert_query2 = '''INSERT INTO aggregated_user(States,years,Quarter,User_brand,User_count,User_percentage) VALUES (%s,%s,%s,%s,%s,%s)'''

data = aggregated_user.values.tolist()
mycursor.executemany(insert_query2,data)
mydb.commit()

# Aggregated_insurance

query3= ("""CREATE TABLE if not exists aggregated_insurance(States VARCHAR(250), 
                                                                      years INT,  
                                                                      Quarter INT, 
                                                                      Name  VARCHAR(250),
                                                                      count  INT,
                                                                      amount bigint )""")
mycursor.execute(query3)
mydb.commit()

# Insert values into table
insert_query3 = '''INSERT INTO aggregated_insurance(States,years,Quarter,Name,count,amount) VALUES (%s,%s,%s,%s,%s,%s)'''

data = aggregated_insurance.values.tolist()
mycursor.executemany(insert_query3,data)
mydb.commit()

# Map_transaction

query4= ("""CREATE TABLE if not exists map_transaction(States VARCHAR(250), 
                                                                      years INT,  
                                                                      Quarter INT, 
                                                                      district_name  VARCHAR(250),
                                                                      Transaction_count  INT,
                                                                      Transaction_amount bigint )""") 
mycursor.execute(query4)
mydb.commit()

# Insert values into table
insert_query4 = '''INSERT INTO map_transaction(States,years,Quarter,district_name,Transaction_count,Transaction_amount) VALUES (%s,%s,%s,%s,%s,%s)'''

data = map_transaction.values.tolist()
mycursor.executemany(insert_query4,data)
mydb.commit()

# Map_user

query5= ("""CREATE TABLE if not exists map_user(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                district_name  VARCHAR(250),
                                                registered_user  INT,
                                                appOpens INT )""") 
mycursor.execute(query5)
mydb.commit()

# Insert values into table
insert_query5 = '''INSERT INTO map_user(States,years,Quarter,district_name,registered_user,appOpens) VALUES (%s,%s,%s,%s,%s,%s)'''

data = map_user.values.tolist()
mycursor.executemany(insert_query5,data)
mydb.commit()

# Map_insurance

query6= ("""CREATE TABLE if not exists map_insurance(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                district_name  VARCHAR(250),
                                                Count  INT,
                                                amount bigint )""") 
mycursor.execute(query6)
mydb.commit()

# Insert values into table
insert_query6 = '''INSERT INTO map_insurance(States,years,Quarter,district_name,Count,amount) VALUES (%s,%s,%s,%s,%s,%s)'''

data = map_insurance.values.tolist()
mycursor.executemany(insert_query6,data)
mydb.commit()

# top_transaction_district

query7= ("""CREATE TABLE if not exists top_transaction_district(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                district_name  VARCHAR(250),
                                                Transaction_count  INT,
                                                Transaction_amount bigint )""") 
mycursor.execute(query7)
mydb.commit()

# Insert values into table
insert_query7 = '''INSERT INTO top_transaction_district(States,years,Quarter,district_name,Transaction_count,Transaction_amount) VALUES (%s,%s,%s,%s,%s,%s)'''

data = top_transaction_district.values.tolist()
mycursor.executemany(insert_query7,data)
mydb.commit()


# top_transaction_pincode

query8= ("""CREATE TABLE if not exists top_transaction_pincode(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                pincode  VARCHAR(250),
                                                Transaction_count  INT,
                                                Transaction_amount bigint )""") 
mycursor.execute(query8)
mydb.commit()

# Insert values into table
insert_query8 = '''INSERT INTO top_transaction_pincode(States,years,Quarter,pincode,Transaction_count,Transaction_amount) VALUES (%s,%s,%s,%s,%s,%s)'''

data = top_transaction_pincode.values.tolist()
mycursor.executemany(insert_query8,data)
mydb.commit()


# top_User_district

query9= ("""CREATE TABLE if not exists top_User_district(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                district_name  VARCHAR(250),
                                                registeredUsers  INT)""") 
mycursor.execute(query9)
mydb.commit()

# Insert values into table
insert_query9 = '''INSERT INTO top_User_district(States,years,Quarter,district_name,registeredUsers) VALUES (%s,%s,%s,%s,%s)'''

data = top_User_district.values.tolist()
mycursor.executemany(insert_query9,data)
mydb.commit()

# top_User_pincode

query10= ("""CREATE TABLE if not exists top_User_pincode(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                pincode INT,
                                                registeredUsers  INT)""") 


mycursor.execute(query10)
mydb.commit()

# Insert values into table
insert_query10 = '''INSERT INTO top_User_pincode(States,years,Quarter,pincode,registeredUsers) VALUES (%s,%s,%s,%s,%s)'''

data = top_User_pincode.values.tolist()
mycursor.executemany(insert_query10,data)
mydb.commit()

# top_insurance_districts

query11= ("""CREATE TABLE if not exists top_insurance_districts(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                district_name VARCHAR(250),
                                                count   INT, 
                                                amount  bigint)""") 


mycursor.execute(query11)
mydb.commit()

# Insert values into table
insert_query11 = '''INSERT INTO top_insurance_districts(States,years,Quarter,district_name,count,amount) VALUES (%s,%s,%s,%s,%s,%s)'''

data = top_insurance_districts.values.tolist()
mycursor.executemany(insert_query11,data)
mydb.commit()

# top_insurance_pincode

query12= ("""CREATE TABLE if not exists top_insurance_pincode(States VARCHAR(250), 
                                                years INT,  
                                                Quarter INT, 
                                                pincode INT,
                                                count   INT, 
                                                amount  bigint)""")


mycursor.execute(query12)
mydb.commit()

# Insert values into table
insert_query12 = '''INSERT INTO top_insurance_pincode(States,years,Quarter,pincode,count,amount) VALUES (%s,%s,%s,%s,%s,%s)'''

data = top_insurance_pincode.values.tolist()
mycursor.executemany(insert_query12,data)
mydb.commit()
